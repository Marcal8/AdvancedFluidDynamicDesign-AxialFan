# %% [markdown]
# # E4 Test bench design

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# ## Previous tasks

# %% [markdown]
# ## Some simple questions

# %% [markdown]
# ## Tasks

# %% [markdown]
# ## Your project
