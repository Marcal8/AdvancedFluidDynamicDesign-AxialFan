# %% [markdown]
# # E2 Error Management

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# ## Previous tasks

# %% [markdown]
# ## Some simple questions

# %% [markdown]
# ## Tasks

# %% [markdown]
# ## Your project
