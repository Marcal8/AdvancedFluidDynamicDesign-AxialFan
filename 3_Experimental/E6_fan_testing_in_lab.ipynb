# %% [markdown]
# # E6 Fan testing in lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# ## Previous tasks

# %% [markdown]
# ## Some simple questions

# %% [markdown]
# ## Tasks

# %% [markdown]
# ## Your project
