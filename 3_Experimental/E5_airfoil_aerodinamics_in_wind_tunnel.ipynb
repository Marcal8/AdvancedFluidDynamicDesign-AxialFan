# %% [markdown]
# # E5 Airfoil aerodynamics in wind tunnel

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# ## Previous tasks

# %% [markdown]
# ## Some simple questions

# %% [markdown]
# ## Tasks

# %% [markdown]
# ## Your project
