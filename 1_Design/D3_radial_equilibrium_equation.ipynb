# %% [markdown]
# # D3 Radial Equilibrium Equation

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# ## Previous tasks

# %% [markdown]
# ## Some simple questions

# %% [markdown]
# ## Tasks

# %% [markdown]
# ## Your project
